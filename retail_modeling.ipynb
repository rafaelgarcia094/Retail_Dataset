# %%
import datetime 

import numpy as np
import pandas as pd

from sklearn.experimental import enable_iterative_imputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import IterativeImputer

# %% [markdown]
# # Dataset Overview
#
# The dataset is composed of three csv files.
#
# Features contains several features valid for each (store, date) tuple from 2010 to 2013
#
# Sales contains the weekly sales value (our prediction target) for each (store, department, date) tuple
#
# Stores contains information about each store in the dataset.

# %%
features_df = pd.read_csv('data/features.csv')
sales_df = pd.read_csv('data/sales.csv')
stores_df = pd.read_csv('data/stores.csv')

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
sales_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %% [markdown]
# Type is a categorical feature with only three possible options. So it's better to one hot encode this feature for an easier modeling process.

# %%
one_hot_encoding = pd.get_dummies(stores_df['Type'])
stores_df = stores_df.join(one_hot_encoding)
stores_df = stores_df.drop(columns=['Type'])
stores_df.head()
# Out:
#    Store    Size  A  B  C
# 0      1  151315  1  0  0
# 1      2  202307  1  0  0
# 2      3   37392  0  1  0
# 3      4  205863  1  0  0
# 4      5   34875  0  1  0

# %% [markdown]
# All three dataframes are grouped into a single one.

# %%
week_sales_df = sales_df.groupby(['Date', 'Store', 'Dept']).agg({'Weekly_Sales': 'sum'}).sort_index()
week_sales_df.reset_index(inplace=True)
training_df = pd.merge(features_df, week_sales_df, how='left', on=["Date", "Store"])
training_df = pd.merge(training_df, stores_df, how='left', on=["Store"])

# %%
training_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  05/02/2010        42.31       2.572        NaN        NaN
# 2      1  05/02/2010        42.31       2.572        NaN        NaN
# 3      1  05/02/2010        42.31       2.572        NaN        NaN
# 4      1  05/02/2010        42.31       2.572        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# 0        NaN        NaN        NaN  211.096358         8.106      False   1.0
# 1        NaN        NaN        NaN  211.096358         8.106      False   2.0
# 2        NaN        NaN        NaN  211.096358         8.106      False   3.0
# 3        NaN        NaN        NaN  211.096358         8.106      False   4.0
# 4        NaN        NaN        NaN  211.096358         8.106      False   5.0
#
#    Weekly_Sales    Size  A  B  C
# 0      24924.50  151315  1  0  0
# 1      50605.27  151315  1  0  0
# 2      13740.12  151315  1  0  0
# 3      39954.04  151315  1  0  0
# 4      32229.38  151315  1  0  0

# %% [markdown]
# The dataframe contains several NaN values that must be removed/replaced

# %%
training_df.isna().sum()
# Out:
# Store                0
# Date                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270892
# MarkDown2       310793
# MarkDown3       284667
# MarkDown4       286859
# MarkDown5       270138
# CPI                585
# Unemployment       585
# IsHoliday            0
# Dept              1755
# Weekly_Sales      1755
# Size                 0
# A                    0
# B                    0
# C                    0
# dtype: int64

# %% [markdown]
# In order to interpolate NaN values, the dataframe must be indexed by DateTime object

# %%
def gen_datetime(date_str):
    return datetime.datetime.strptime(date_str, '%d/%m/%Y')

training_df['DateTime'] = training_df['Date'].map(gen_datetime)

# %%
training_df = training_df.set_index(['DateTime', 'Store', 'Dept']).sort_index()

# %%
training_df.head()
# Out:
#                              Date  Temperature  Fuel_Price  MarkDown1  \
# DateTime   Store Dept
# 2010-02-05 1     1.0   05/02/2010        42.31       2.572        NaN
#                  2.0   05/02/2010        42.31       2.572        NaN
#                  3.0   05/02/2010        42.31       2.572        NaN
#                  4.0   05/02/2010        42.31       2.572        NaN
#                  5.0   05/02/2010        42.31       2.572        NaN
#
#                        MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# DateTime   Store Dept
# 2010-02-05 1     1.0         NaN        NaN        NaN        NaN  211.096358
#                  2.0         NaN        NaN        NaN        NaN  211.096358
#                  3.0         NaN        NaN        NaN        NaN  211.096358
#                  4.0         NaN        NaN        NaN        NaN  211.096358
#                  5.0         NaN        NaN        NaN        NaN  211.096358
#
#                        Unemployment  IsHoliday  Weekly_Sales    Size  A  B  C
# DateTime   Store Dept
# 2010-02-05 1     1.0          8.106      False      24924.50  151315  1  0  0
#                  2.0          8.106      False      50605.27  151315  1  0  0
#                  3.0          8.106      False      13740.12  151315  1  0  0
#                  4.0          8.106      False      39954.04  151315  1  0  0
#                  5.0          8.106      False      32229.38  151315  1  0  0

# %%
training_df['CPI'] = training_df['CPI'].interpolate(method='linear')
training_df['Unemployment'] = training_df['Unemployment'].interpolate(method='linear')

# %%
training_df.isna().sum()
# Out:
# Date                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270892
# MarkDown2       310793
# MarkDown3       284667
# MarkDown4       286859
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday            0
# Weekly_Sales      1755
# Size                 0
# A                    0
# B                    0
# C                    0
# dtype: int64

# %%
training_df['MarkDown1'] = IterativeImputer(random_state=0).fit_transform(training_df['MarkDown1'].values.reshape(-1, 1))
training_df['MarkDown2'] = IterativeImputer(random_state=0).fit_transform(training_df['MarkDown2'].values.reshape(-1, 1))
training_df['MarkDown3'] = IterativeImputer(random_state=0).fit_transform(training_df['MarkDown3'].values.reshape(-1, 1))
training_df['MarkDown4'] = IterativeImputer(random_state=0).fit_transform(training_df['MarkDown4'].values.reshape(-1, 1))
training_df['MarkDown5'] = IterativeImputer(random_state=0).fit_transform(training_df['MarkDown5'].values.reshape(-1, 1))

# %%
training_df = training_df.reset_index()

# %%
training_df = training_df[training_df['Dept'].notna()]

# %%
training_df.isna().sum()
# Out:
# DateTime        0
# Store           0
# Dept            0
# Date            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday       0
# Weekly_Sales    0
# Size            0
# A               0
# B               0
# C               0
# dtype: int64

# %%
training_df.head()
# Out:
#     DateTime  Store  Dept        Date  Temperature  Fuel_Price    MarkDown1  \
# 0 2010-02-05      1   1.0  05/02/2010        42.31       2.572  7246.604247
# 1 2010-02-05      1   2.0  05/02/2010        42.31       2.572  7246.604247
# 2 2010-02-05      1   3.0  05/02/2010        42.31       2.572  7246.604247
# 3 2010-02-05      1   4.0  05/02/2010        42.31       2.572  7246.604247
# 4 2010-02-05      1   5.0  05/02/2010        42.31       2.572  7246.604247
#
#      MarkDown2    MarkDown3    MarkDown4    MarkDown5         CPI  \
# 0  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 1  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 2  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 3  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 4  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
#
#    Unemployment  IsHoliday  Weekly_Sales    Size  A  B  C
# 0         8.106      False      24924.50  151315  1  0  0
# 1         8.106      False      50605.27  151315  1  0  0
# 2         8.106      False      13740.12  151315  1  0  0
# 3         8.106      False      39954.04  151315  1  0  0
# 4         8.106      False      32229.38  151315  1  0  0

# %% [markdown]
# Date should be decomposed into Year and a cyclical feature for Day of Year

# %%
training_df['Year'] = training_df['Date'].map(lambda x: int(x[-4:]))

# %%
training_df.head()
# Out:
#     DateTime  Store  Dept        Date  Temperature  Fuel_Price    MarkDown1  \
# 0 2010-02-05      1   1.0  05/02/2010        42.31       2.572  7246.604247
# 1 2010-02-05      1   2.0  05/02/2010        42.31       2.572  7246.604247
# 2 2010-02-05      1   3.0  05/02/2010        42.31       2.572  7246.604247
# 3 2010-02-05      1   4.0  05/02/2010        42.31       2.572  7246.604247
# 4 2010-02-05      1   5.0  05/02/2010        42.31       2.572  7246.604247
#
#      MarkDown2    MarkDown3    MarkDown4    MarkDown5         CPI  \
# 0  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 1  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 2  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 3  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
# 4  3337.597289  1449.098932  3382.019834  4618.743783  211.096358
#
#    Unemployment  IsHoliday  Weekly_Sales    Size  A  B  C  Year
# 0         8.106      False      24924.50  151315  1  0  0  2010
# 1         8.106      False      50605.27  151315  1  0  0  2010
# 2         8.106      False      13740.12  151315  1  0  0  2010
# 3         8.106      False      39954.04  151315  1  0  0  2010
# 4         8.106      False      32229.38  151315  1  0  0  2010

# %%
def day_of_year(date_str):
    date = datetime.datetime.strptime(date_str, '%d/%m/%Y')
    return date.timetuple().tm_yday

training_df['DayOfYear'] = training_df['Date'].map(day_of_year)
training_df['DayOfYearCos'] = np.cos(training_df['DayOfYear'])
training_df['DayOfYearSin'] = np.sin(training_df['DayOfYear'])

# %%
training_df.head()
# Out:
#     DateTime  Store  Dept        Date  Temperature  Fuel_Price    MarkDown1  \
# 0 2010-02-05      1   1.0  05/02/2010        42.31       2.572  7246.604247
# 1 2010-02-05      1   2.0  05/02/2010        42.31       2.572  7246.604247
# 2 2010-02-05      1   3.0  05/02/2010        42.31       2.572  7246.604247
# 3 2010-02-05      1   4.0  05/02/2010        42.31       2.572  7246.604247
# 4 2010-02-05      1   5.0  05/02/2010        42.31       2.572  7246.604247
#
#      MarkDown2    MarkDown3    MarkDown4  ...  IsHoliday  Weekly_Sales  \
# 0  3337.597289  1449.098932  3382.019834  ...      False      24924.50
# 1  3337.597289  1449.098932  3382.019834  ...      False      50605.27
# 2  3337.597289  1449.098932  3382.019834  ...      False      13740.12
# 3  3337.597289  1449.098932  3382.019834  ...      False      39954.04
# 4  3337.597289  1449.098932  3382.019834  ...      False      32229.38
#
#      Size  A  B  C  Year  DayOfYear  DayOfYearCos  DayOfYearSin
# 0  151315  1  0  0  2010         36     -0.127964     -0.991779
# 1  151315  1  0  0  2010         36     -0.127964     -0.991779
# 2  151315  1  0  0  2010         36     -0.127964     -0.991779
# 3  151315  1  0  0  2010         36     -0.127964     -0.991779
# 4  151315  1  0  0  2010         36     -0.127964     -0.991779
#
# [5 rows x 23 columns]

# %%
training_df = training_df.drop(columns=['Date'])

# %%
training_df.head()
# Out:
#     DateTime  Store  Dept  Temperature  Fuel_Price    MarkDown1    MarkDown2  \
# 0 2010-02-05      1   1.0        42.31       2.572  7246.604247  3337.597289
# 1 2010-02-05      1   2.0        42.31       2.572  7246.604247  3337.597289
# 2 2010-02-05      1   3.0        42.31       2.572  7246.604247  3337.597289
# 3 2010-02-05      1   4.0        42.31       2.572  7246.604247  3337.597289
# 4 2010-02-05      1   5.0        42.31       2.572  7246.604247  3337.597289
#
#      MarkDown3    MarkDown4    MarkDown5  ...  IsHoliday  Weekly_Sales  \
# 0  1449.098932  3382.019834  4618.743783  ...      False      24924.50
# 1  1449.098932  3382.019834  4618.743783  ...      False      50605.27
# 2  1449.098932  3382.019834  4618.743783  ...      False      13740.12
# 3  1449.098932  3382.019834  4618.743783  ...      False      39954.04
# 4  1449.098932  3382.019834  4618.743783  ...      False      32229.38
#
#      Size  A  B  C  Year  DayOfYear  DayOfYearCos  DayOfYearSin
# 0  151315  1  0  0  2010         36     -0.127964     -0.991779
# 1  151315  1  0  0  2010         36     -0.127964     -0.991779
# 2  151315  1  0  0  2010         36     -0.127964     -0.991779
# 3  151315  1  0  0  2010         36     -0.127964     -0.991779
# 4  151315  1  0  0  2010         36     -0.127964     -0.991779
#
# [5 rows x 22 columns]

# %% [markdown]
# Normalizing values between 0 and 1

# %%
training_df['Store'] = MinMaxScaler().fit_transform(training_df['Store'].values.reshape((-1, 1)))
training_df['Temperature'] = MinMaxScaler().fit_transform(training_df['Temperature'].values.reshape((-1, 1)))
training_df['Fuel_Price'] = MinMaxScaler().fit_transform(training_df['Fuel_Price'].values.reshape((-1, 1)))
training_df['MarkDown1'] = MinMaxScaler().fit_transform(training_df['MarkDown1'].values.reshape((-1, 1)))
training_df['MarkDown2'] = MinMaxScaler().fit_transform(training_df['MarkDown2'].values.reshape((-1, 1)))
training_df['MarkDown3'] = MinMaxScaler().fit_transform(training_df['MarkDown3'].values.reshape((-1, 1)))
training_df['MarkDown4'] = MinMaxScaler().fit_transform(training_df['MarkDown4'].values.reshape((-1, 1)))
training_df['MarkDown5'] = MinMaxScaler().fit_transform(training_df['MarkDown5'].values.reshape((-1, 1)))
training_df['CPI'] = MinMaxScaler().fit_transform(training_df['CPI'].values.reshape((-1, 1)))
training_df['Unemployment'] = MinMaxScaler().fit_transform(training_df['Unemployment'].values.reshape((-1, 1)))
training_df['IsHoliday'] = training_df['IsHoliday'].astype(int)
training_df['Dept'] = MinMaxScaler().fit_transform(training_df['Dept'].values.reshape((-1, 1)))
training_df['Weekly_Sales'] = MinMaxScaler().fit_transform(training_df['Weekly_Sales'].values.reshape((-1, 1)))
training_df['Size'] = MinMaxScaler().fit_transform(training_df['Size'].values.reshape((-1, 1)))

# %%
training_df.head()
# Out:
#     DateTime  Store      Dept  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0 2010-02-05    0.0  0.000000     0.434149      0.0501   0.081744   0.034388
# 1 2010-02-05    0.0  0.010204     0.434149      0.0501   0.081744   0.034388
# 2 2010-02-05    0.0  0.020408     0.434149      0.0501   0.081744   0.034388
# 3 2010-02-05    0.0  0.030612     0.434149      0.0501   0.081744   0.034388
# 4 2010-02-05    0.0  0.040816     0.434149      0.0501   0.081744   0.034388
#
#    MarkDown3  MarkDown4  MarkDown5  ...  IsHoliday  Weekly_Sales      Size  A  \
# 0   0.010435    0.05012   0.041368  ...          0      0.042851  0.630267  1
# 1   0.010435    0.05012   0.041368  ...          0      0.079638  0.630267  1
# 2   0.010435    0.05012   0.041368  ...          0      0.026829  0.630267  1
# 3   0.010435    0.05012   0.041368  ...          0      0.064380  0.630267  1
# 4   0.010435    0.05012   0.041368  ...          0      0.053315  0.630267  1
#
#    B  C  Year  DayOfYear  DayOfYearCos  DayOfYearSin
# 0  0  0  2010         36     -0.127964     -0.991779
# 1  0  0  2010         36     -0.127964     -0.991779
# 2  0  0  2010         36     -0.127964     -0.991779
# 3  0  0  2010         36     -0.127964     -0.991779
# 4  0  0  2010         36     -0.127964     -0.991779
#
# [5 rows x 22 columns]

# %%
training_df.tail()
# Out:
#          DateTime  Store      Dept  Temperature  Fuel_Price  MarkDown1  \
# 421565 2012-10-26    1.0  0.938776     0.595988    0.706413   0.045333
# 421566 2012-10-26    1.0  0.948980     0.595988    0.706413   0.045333
# 421567 2012-10-26    1.0  0.959184     0.595988    0.706413   0.045333
# 421568 2012-10-26    1.0  0.979592     0.595988    0.706413   0.045333
# 421569 2012-10-26    1.0  0.989796     0.595988    0.706413   0.045333
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5  ...  IsHoliday  \
# 421565   0.003091   0.000911   0.003138   0.006672  ...          0
# 421566   0.003091   0.000911   0.003138   0.006672  ...          0
# 421567   0.003091   0.000911   0.003138   0.006672  ...          0
# 421568   0.003091   0.000911   0.003138   0.006672  ...          0
# 421569   0.003091   0.000911   0.003138   0.006672  ...          0
#
#         Weekly_Sales      Size  A  B  C  Year  DayOfYear  DayOfYearCos  \
# 421565      0.010710  0.451136  0  1  0  2012        300     -0.022097
# 421566      0.014600  0.451136  0  1  0  2012        300     -0.022097
# 421567      0.087391  0.451136  0  1  0  2012        300     -0.022097
# 421568      0.016913  0.451136  0  1  0  2012        300     -0.022097
# 421569      0.008689  0.451136  0  1  0  2012        300     -0.022097
#
#         DayOfYearSin
# 421565     -0.999756
# 421566     -0.999756
# 421567     -0.999756
# 421568     -0.999756
# 421569     -0.999756
#
# [5 rows x 22 columns]

# %% [markdown]
# Split training set from 2010 to 2011 and prediction set from 2012 to 2013

# %%
training_df = training_df.set_index('DateTime')

# %%
training_set_df = training_df[:'2012-01-01']

# %%
training_set_df.head()
# Out:
#             Store      Dept  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# DateTime
# 2010-02-05    0.0  0.000000     0.434149      0.0501   0.081744   0.034388
# 2010-02-05    0.0  0.010204     0.434149      0.0501   0.081744   0.034388
# 2010-02-05    0.0  0.020408     0.434149      0.0501   0.081744   0.034388
# 2010-02-05    0.0  0.030612     0.434149      0.0501   0.081744   0.034388
# 2010-02-05    0.0  0.040816     0.434149      0.0501   0.081744   0.034388
#
#             MarkDown3  MarkDown4  MarkDown5     CPI  ...  IsHoliday  \
# DateTime                                             ...
# 2010-02-05   0.010435    0.05012   0.041368  0.8405  ...          0
# 2010-02-05   0.010435    0.05012   0.041368  0.8405  ...          0
# 2010-02-05   0.010435    0.05012   0.041368  0.8405  ...          0
# 2010-02-05   0.010435    0.05012   0.041368  0.8405  ...          0
# 2010-02-05   0.010435    0.05012   0.041368  0.8405  ...          0
#
#             Weekly_Sales      Size  A  B  C  Year  DayOfYear  DayOfYearCos  \
# DateTime
# 2010-02-05      0.042851  0.630267  1  0  0  2010         36     -0.127964
# 2010-02-05      0.079638  0.630267  1  0  0  2010         36     -0.127964
# 2010-02-05      0.026829  0.630267  1  0  0  2010         36     -0.127964
# 2010-02-05      0.064380  0.630267  1  0  0  2010         36     -0.127964
# 2010-02-05      0.053315  0.630267  1  0  0  2010         36     -0.127964
#
#             DayOfYearSin
# DateTime
# 2010-02-05     -0.991779
# 2010-02-05     -0.991779
# 2010-02-05     -0.991779
# 2010-02-05     -0.991779
# 2010-02-05     -0.991779
#
# [5 rows x 21 columns]

# %%
training_set_df.tail()
# Out:
#             Store      Dept  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# DateTime
# 2011-12-30    1.0  0.938776     0.389922    0.459419   0.040657   0.421885
# 2011-12-30    1.0  0.948980     0.389922    0.459419   0.040657   0.421885
# 2011-12-30    1.0  0.959184     0.389922    0.459419   0.040657   0.421885
# 2011-12-30    1.0  0.979592     0.389922    0.459419   0.040657   0.421885
# 2011-12-30    1.0  0.989796     0.389922    0.459419   0.040657   0.421885
#
#             MarkDown3  MarkDown4  MarkDown5       CPI  ...  IsHoliday  \
# DateTime                                               ...
# 2011-12-30   0.002235   0.005294   0.005673  0.622702  ...          1
# 2011-12-30   0.002235   0.005294   0.005673  0.622702  ...          1
# 2011-12-30   0.002235   0.005294   0.005673  0.622702  ...          1
# 2011-12-30   0.002235   0.005294   0.005673  0.622702  ...          1
# 2011-12-30   0.002235   0.005294   0.005673  0.622702  ...          1
#
#             Weekly_Sales      Size  A  B  C  Year  DayOfYear  DayOfYearCos  \
# DateTime
# 2011-12-30      0.009190  0.451136  0  1  0  2011        364      0.911143
# 2011-12-30      0.011414  0.451136  0  1  0  2011        364      0.911143
# 2011-12-30      0.067432  0.451136  0  1  0  2011        364      0.911143
# 2011-12-30      0.015125  0.451136  0  1  0  2011        364      0.911143
# 2011-12-30      0.007939  0.451136  0  1  0  2011        364      0.911143
#
#             DayOfYearSin
# DateTime
# 2011-12-30     -0.412091
# 2011-12-30     -0.412091
# 2011-12-30     -0.412091
# 2011-12-30     -0.412091
# 2011-12-30     -0.412091
#
# [5 rows x 21 columns]

# %%
test_set_df = training_df['2012-01-01':]

# %%
test_set_df.head()
# Out:
#             Store      Dept  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# DateTime
# 2012-01-06    0.0  0.000000     0.499706    0.343186   0.070811   0.210706
# 2012-01-06    0.0  0.010204     0.499706    0.343186   0.070811   0.210706
# 2012-01-06    0.0  0.020408     0.499706    0.343186   0.070811   0.210706
# 2012-01-06    0.0  0.030612     0.499706    0.343186   0.070811   0.210706
# 2012-01-06    0.0  0.040816     0.499706    0.343186   0.070811   0.210706
#
#             MarkDown3  MarkDown4  MarkDown5       CPI  ...  IsHoliday  \
# DateTime                                               ...
# 2012-01-06   0.001216   0.021488   0.077021  0.925683  ...          0
# 2012-01-06   0.001216   0.021488   0.077021  0.925683  ...          0
# 2012-01-06   0.001216   0.021488   0.077021  0.925683  ...          0
# 2012-01-06   0.001216   0.021488   0.077021  0.925683  ...          0
# 2012-01-06   0.001216   0.021488   0.077021  0.925683  ...          0
#
#             Weekly_Sales      Size  A  B  C  Year  DayOfYear  DayOfYearCos  \
# DateTime
# 2012-01-06      0.030880  0.630267  1  0  0  2012          6       0.96017
# 2012-01-06      0.070865  0.630267  1  0  0  2012          6       0.96017
# 2012-01-06      0.027095  0.630267  1  0  0  2012          6       0.96017
# 2012-01-06      0.065772  0.630267  1  0  0  2012          6       0.96017
# 2012-01-06      0.040245  0.630267  1  0  0  2012          6       0.96017
#
#             DayOfYearSin
# DateTime
# 2012-01-06     -0.279415
# 2012-01-06     -0.279415
# 2012-01-06     -0.279415
# 2012-01-06     -0.279415
# 2012-01-06     -0.279415
#
# [5 rows x 21 columns]

# %%
test_set_df.tail()
# Out:
#             Store      Dept  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# DateTime
# 2012-10-26    1.0  0.938776     0.595988    0.706413   0.045333   0.003091
# 2012-10-26    1.0  0.948980     0.595988    0.706413   0.045333   0.003091
# 2012-10-26    1.0  0.959184     0.595988    0.706413   0.045333   0.003091
# 2012-10-26    1.0  0.979592     0.595988    0.706413   0.045333   0.003091
# 2012-10-26    1.0  0.989796     0.595988    0.706413   0.045333   0.003091
#
#             MarkDown3  MarkDown4  MarkDown5       CPI  ...  IsHoliday  \
# DateTime                                               ...
# 2012-10-26   0.000911   0.003138   0.006672  0.654796  ...          0
# 2012-10-26   0.000911   0.003138   0.006672  0.654796  ...          0
# 2012-10-26   0.000911   0.003138   0.006672  0.654796  ...          0
# 2012-10-26   0.000911   0.003138   0.006672  0.654796  ...          0
# 2012-10-26   0.000911   0.003138   0.006672  0.654796  ...          0
#
#             Weekly_Sales      Size  A  B  C  Year  DayOfYear  DayOfYearCos  \
# DateTime
# 2012-10-26      0.010710  0.451136  0  1  0  2012        300     -0.022097
# 2012-10-26      0.014600  0.451136  0  1  0  2012        300     -0.022097
# 2012-10-26      0.087391  0.451136  0  1  0  2012        300     -0.022097
# 2012-10-26      0.016913  0.451136  0  1  0  2012        300     -0.022097
# 2012-10-26      0.008689  0.451136  0  1  0  2012        300     -0.022097
#
#             DayOfYearSin
# DateTime
# 2012-10-26     -0.999756
# 2012-10-26     -0.999756
# 2012-10-26     -0.999756
# 2012-10-26     -0.999756
# 2012-10-26     -0.999756
#
# [5 rows x 21 columns]

# %%
X_training = training_set_df.drop(columns=['Weekly_Sales', 'Year', 'DayOfYear']).values
y_training = training_set_df['Weekly_Sales'].values
X_prediction = test_set_df.drop(columns=['Weekly_Sales', 'Year', 'DayOfYear']).values
y_prediction = test_set_df['Weekly_Sales'].values

# %%
X_training.shape, y_training.shape, X_prediction.shape, y_prediction.shape
# Out:
# ((294132, 18), (294132,), (127438, 18), (127438,))

# %% [markdown]
# Split training set into train and test set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_training, y_training, test_size=0.33, random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((197068, 18), (197068,), (97064, 18), (97064,))

# %% [markdown]
# Decision Tree is able to predict value of unseen years with score of 0.85

# %%
from sklearn.tree import DecisionTreeRegressor

dtr_regressor = DecisionTreeRegressor(max_depth=50, min_samples_leaf=200, random_state=0)

# %%
dtr_regressor = dtr_regressor.fit(X_train, y_train)
dtr_regressor.score(X_test, y_test)
# Out:
# 0.8339429299658346

# %%
future_pred = dtr_regressor.predict(X_prediction)
dtr_regressor.score(X_prediction, y_prediction)
# Out:
# 0.8507626393467799

# %% [markdown]
# Random Forest is able to predict value of unseen years with score of 0.86

# %%
from sklearn.ensemble import RandomForestRegressor

rfr_regressor = RandomForestRegressor(n_estimators=20, max_depth=100, min_samples_leaf=150, random_state=0)

# %%
rfr_regressor = rfr_regressor.fit(X_train, y_train)
rfr_regressor.score(X_test, y_test)
# Out:
# 0.839565073492495

# %%
future_pred = rfr_regressor.predict(X_prediction)
rfr_regressor.score(X_prediction, y_prediction)
# Out:
# 0.8615569217734452

# %% [markdown]
# Gradient Boosting Regressor is able to predict the value of unseen years with score of 0.87

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr_regressor = GradientBoostingRegressor(n_estimators=20, max_depth=150, min_samples_leaf=150, random_state=0)

# %%
gbr_regressor = gbr_regressor.fit(X_train, y_train)
gbr_regressor.score(X_test, y_test)
# Out:
# 0.8833556278576009

# %%
future_pred = gbr_regressor.predict(X_prediction)
gbr_regressor.score(X_prediction, y_prediction)
# Out:
# 0.8690338706793365
